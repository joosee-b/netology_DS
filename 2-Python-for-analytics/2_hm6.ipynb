# %%
# Задание 1
# Используем файл keywords.csv.
 
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце 'region' пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим 'undefined'.
 
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
 
# geo_data = {
 
#     'Центр': ['москва', 'тула', 'ярославль'],
 
#     'Северо-Запад': ['петербург', 'псков', 'мурманск'],
 
#     'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
 
# }
 
# Результат классификации запишите в отдельный столбец region.
 
import pandas as pd
geo_data = {
 'Центр': ['москва', 'тула', 'ярославль'],
 'Северо-Запад': ['петербург', 'псков', 'мурманск'],
 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск'] 
}
df = pd.read_csv("keywords.csv")

for key, mass in geo_data.items():
    for city in mass:
        results = df[df.keyword.str.startswith(city)]
        
        for row in results.iterrows():
            idrow = row[0]
            df.at[idrow, 'region'] = key

print(df[df.region == 'Центр'])
print(df[df.region == 'Северо-Запад'])
print(df[df.region == 'Дальний Восток'])
# Out:
#                                                  keyword   shows region
# 1259                                              москва  153050  Центр
# 5983                                   москва третий рим   43182  Центр
# 6075                                           ярославль   41720  Центр
# 6999                                           москва 24   37459  Центр
# 7103                                         москва сити   37022  Центр
# 7339                              москва слезам не верит   35857  Центр
# 8132                                       москва погода  151701  Центр
# 11785                                               тула   23898  Центр
# 15370                                         москвариум   19220  Центр
# 16175  москва слезам не верит смотреть в хорошем каче...   18407  Центр
# 18843                                          москва фм   16400  Центр
# 39920                                       москва карта   15769  Центр
# 40095                                       москва время   39941  Центр
# 44863                      москва симферополь авиабилеты   16043  Центр
# 45309             москва слезам не верит смотреть онлайн    7976  Центр
# 47121                             москва сочи авиабилеты   13146  Центр
# 52463                             москва санкт петербург    9756  Центр
# 52727                москва третий рим православный сайт    6630  Центр
# 55882                    ярославль достопримечательности    6306  Центр
# 57123                   москвариум вднх официальный сайт    6325  Центр
# 57421                                       москва метро   68024  Центр
# 59617                      москва слезам не верит актеры    6408  Центр
# 66224                                   москва сити фото    6086  Центр
# 68181                  москва слезам не верит фильм 1980    5173  Центр
# 70611                       москва 24 онлайн прямой эфир    5055  Центр
# 71891  москва слезам не верит смотреть бесплатно в хо...    5167  Центр
# 74372                                       москва 3 рим    5057  Центр
# 74724                                       москва минск    6023  Центр
# 81003                    москва я терплю тебя фильм 2016    4468  Центр
# 83053           москва слезам не верит фильм 1980 актеры    4320  Центр
# 85584                                    москва панорама    4396  Центр
# 87259                                        москва сочи    4822  Центр
# 92517                                   ярославль погода   31930  Центр
# 93321                                       москва авито  979292  Центр
# 93819                             москва нижний новгород    6220  Центр
# 98183                москва октябрьская это какой вокзал    3696  Центр
#                                                  keyword  shows        region
# 5673                           петербургское образование  44184  Северо-Запад
# 8977                                            мурманск  29984  Северо-Запад
# 11080                         петербургская недвижимость  25147  Северо-Запад
# 11222                                              псков  24885  Северо-Запад
# 11348      петербургское образование электронный дневник  24061  Северо-Запад
# 20823                                          петербург  14859  Северо-Запад
# 23012                           псковская лента новостей  13596  Северо-Запад
# 33197   петербургская сбытовая компания официальный сайт   9966  Северо-Запад
# 42511                                        псковфишинг   7946  Северо-Запад
# 56071                    петербургская сбытовая компания   6185  Северо-Запад
# 73816                                    псковское порно   4895  Северо-Запад
# 75510                                  псковская область   4714  Северо-Запад
# 75889  петербургская недвижимость официальный сайт са...   5601  Северо-Запад
# 83368                                 мурманская область   4304  Северо-Запад
# 83750                         псково печерский монастырь   4303  Северо-Запад
# 84400                                    мурманск погода  17908  Северо-Запад
# 86070                              петербургский дневник   4198  Северо-Запад
# 88413                          петербург только по любви   4142  Северо-Запад
#                                        keyword  shows          region
# 5858                               владивосток  43038  Дальний Восток
# 9084                                 хабаровск  29655  Дальний Восток
# 21445                                  сахалин  14494  Дальний Восток
# 38863                        владивосток время  14794  Дальний Восток
# 46720                          хабаровск время  10777  Дальний Восток
# 46786  хабаровские живодерки последние новости   7321  Дальний Восток
# 51779                    хабаровские живодерки   6657  Дальний Восток
# 68148                         хабаровский край   5177  Дальний Восток

# %%
# Задание 2
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# - оценка 2 и меньше - низкий рейтинг
# - оценка 4 и меньше - средний рейтинг
# - оценка 4.5 и 5 - высокий рейтинг
 
# Результат классификации запишите в столбец class
import pandas as pd
df_movies = pd.read_csv("csvs/movies.csv")
df_ratings = pd.read_csv("csvs/ratings.csv")

df_merge = df_ratings.join(df_movies.set_index('movieId'), on='movieId')

rating = df_merge.groupby('movieId')['rating'].mean()

df_merged = df_movies.join(rating, on='movieId')

df_merged.loc[df_merged.rating <= 2, 'rating_level'] = 'low'
df_merged.loc[(df_merged.rating <= 4) & (df_merged.rating > 2), 'rating_level'] = 'middle'
df_merged.loc[df_merged.rating >= 4.5, 'rating_level'] = 'hight'
df_merged
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 5           6                                        Heat (1995)
# 6           7                                     Sabrina (1995)
# 7           8                                Tom and Huck (1995)
# 8           9                                Sudden Death (1995)
# 9          10                                   GoldenEye (1995)
# 10         11                     American President, The (1995)
# 11         12                 Dracula: Dead and Loving It (1995)
# 12         13                                       Balto (1995)
# 13         14                                       Nixon (1995)
# 14         15                            Cutthroat Island (1995)
# 15         16                                      Casino (1995)
# 16         17                       Sense and Sensibility (1995)
# 17         18                                  Four Rooms (1995)
# 18         19              Ace Ventura: When Nature Calls (1995)
# 19         20                                 Money Train (1995)
# 20         21                                  Get Shorty (1995)
# 21         22                                     Copycat (1995)
# 22         23                                   Assassins (1995)
# 23         24                                      Powder (1995)
# 24         25                           Leaving Las Vegas (1995)
# 25         26                                     Othello (1995)
# 26         27                                Now and Then (1995)
# 27         28                                  Persuasion (1995)
# 28         29  City of Lost Children, The (Cité des enfants p...
# 29         30  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# ...       ...                                                ...
# 9095   159690  Teenage Mutant Ninja Turtles: Out of the Shado...
# 9096   159755          Popstar: Never Stop Never Stopping (2016)
# 9097   159858                             The Conjuring 2 (2016)
# 9098   159972                     Approaching the Unknown (2016)
# 9099   160080                                Ghostbusters (2016)
# 9100   160271                        Central Intelligence (2016)
# 9101   160438                                Jason Bourne (2016)
# 9102   160440                             The Maid's Room (2014)
# 9103   160563                        The Legend of Tarzan (2016)
# 9104   160565                    The Purge: Election Year (2016)
# 9105   160567              Mike & Dave Need Wedding Dates (2016)
# 9106   160590                         Survive and Advance (2013)
# 9107   160656                                    Tallulah (2016)
# 9108   160718                                       Piper (2016)
# 9109   160954                                       Nerve (2016)
# 9110   161084                       My Friend Rockefeller (2015)
# 9111   161155                                   Sunspring (2016)
# 9112   161336                  Author: The JT LeRoy Story (2016)
# 9113   161582                          Hell or High Water (2016)
# 9114   161594               Kingsglaive: Final Fantasy XV (2016)
# 9115   161830                                        Body (2015)
# 9116   161918                Sharknado 4: The 4th Awakens (2016)
# 9117   161944              The Last Brickmaker in America (2001)
# 9118   162376                                    Stranger Things
# 9119   162542                                      Rustom (2016)
# 9120   162672                                Mohenjo Daro (2016)
# 9121   163056                               Shin Godzilla (2016)
# 9122   163949  The Beatles: Eight Days a Week - The Touring Y...
# 9123   164977                           The Gay Desperado (1936)
# 9124   164979                              Women of '69, Unboxed
#
#                                                genres    rating rating_level
# 0         Adventure|Animation|Children|Comedy|Fantasy  3.872470       middle
# 1                          Adventure|Children|Fantasy  3.401869       middle
# 2                                      Comedy|Romance  3.161017       middle
# 3                                Comedy|Drama|Romance  2.384615       middle
# 4                                              Comedy  3.267857       middle
# 5                               Action|Crime|Thriller  3.884615       middle
# 6                                      Comedy|Romance  3.283019       middle
# 7                                  Adventure|Children  3.800000       middle
# 8                                              Action  3.150000       middle
# 9                           Action|Adventure|Thriller  3.450820       middle
# 10                               Comedy|Drama|Romance  3.689024       middle
# 11                                      Comedy|Horror  2.861111       middle
# 12                       Adventure|Animation|Children  3.937500       middle
# 13                                              Drama  3.451613       middle
# 14                           Action|Adventure|Romance  2.318182       middle
# 15                                        Crime|Drama  3.948864       middle
# 16                                      Drama|Romance  3.924419       middle
# 17                                             Comedy  3.288462       middle
# 18                                             Comedy  2.597826       middle
# 19                 Action|Comedy|Crime|Drama|Thriller  2.538462       middle
# 20                              Comedy|Crime|Thriller  3.536842       middle
# 21                Crime|Drama|Horror|Mystery|Thriller  3.355263       middle
# 22                              Action|Crime|Thriller  3.090909       middle
# 23                                       Drama|Sci-Fi  3.044118       middle
# 24                                      Drama|Romance  3.742574       middle
# 25                                              Drama  4.100000          NaN
# 26                                     Children|Drama  3.142857       middle
# 27                                      Drama|Romance  4.083333          NaN
# 28             Adventure|Drama|Fantasy|Mystery|Sci-Fi  4.025000          NaN
# 29                                        Crime|Drama  4.050000          NaN
# ...                                               ...       ...          ...
# 9095                          Action|Adventure|Comedy  2.000000          low
# 9096                                           Comedy  1.000000          low
# 9097                                           Horror  3.750000       middle
# 9098                            Drama|Sci-Fi|Thriller  0.500000          low
# 9099                      Action|Comedy|Horror|Sci-Fi  1.000000          low
# 9100                                    Action|Comedy  2.500000       middle
# 9101                                           Action  4.250000          NaN
# 9102                                         Thriller  1.500000          low
# 9103                                 Action|Adventure  2.500000       middle
# 9104                             Action|Horror|Sci-Fi  2.000000          low
# 9105                                           Comedy  4.000000       middle
# 9106                               (no genres listed)  5.000000        hight
# 9107                                            Drama  3.500000       middle
# 9108                                        Animation  4.000000       middle
# 9109                                   Drama|Thriller       NaN          NaN
# 9110                                      Documentary  2.500000       middle
# 9111                                           Sci-Fi  0.500000          low
# 9112                                      Documentary       NaN          NaN
# 9113                                      Crime|Drama       NaN          NaN
# 9114  Action|Adventure|Animation|Drama|Fantasy|Sci-Fi  3.000000       middle
# 9115                            Drama|Horror|Thriller  1.000000          low
# 9116                   Action|Adventure|Horror|Sci-Fi  1.500000          low
# 9117                                            Drama  5.000000        hight
# 9118                                            Drama  4.500000        hight
# 9119                                 Romance|Thriller  5.000000        hight
# 9120                          Adventure|Drama|Romance  3.000000       middle
# 9121                  Action|Adventure|Fantasy|Sci-Fi       NaN          NaN
# 9122                                      Documentary  5.000000        hight
# 9123                                           Comedy       NaN          NaN
# 9124                                      Documentary       NaN          NaN
#
# [9125 rows x 5 columns]

# %%
# Задание 3
# Посчитайте среднее значение Lifetime киноманов (пользователи, которые поставили 100 и более рейтингов). 
# Под Lifetime понимается разница между максимальным и минимальным значением timestamp для каждого пользователя. 
# Ответ дайте в днях.

import pandas as pd
df_ratings = pd.read_csv("csvs/ratings.csv")

df_ratings['count_votes'] = 1

df_grouped = df_ratings.groupby('userId').sum()
users_ids = [u[0] for u in df_grouped[df_grouped.count_votes >= 100].iterrows()] # kinomans

mins = df_ratings[df_ratings.userId.isin(users_ids)].groupby('userId').min(axis='timestamp')
maxs = df_ratings[df_ratings.userId.isin(users_ids)].groupby('userId').max(axis='timestamp')

df_min_max = mins.merge(maxs, on='userId', suffixes=['_min', '_max'])
df_min_max['diff_days'] = (df_min_max.timestamp_max - df_min_max.timestamp_min)/60/60/24

df_min_max.loc['avg'] = df_min_max.mean() # calculate avg
df_min_max
# Out:
#         movieId_min  rating_min  timestamp_min  count_votes_min  \
# userId
# 4         10.000000    1.000000   9.497787e+08              1.0
# 5          3.000000    1.500000   1.163373e+09              1.0
# 8         32.000000    0.500000   1.154389e+09              1.0
# 15         1.000000    0.500000   9.979372e+08              1.0
# 17         6.000000    0.500000   1.127469e+09              1.0
# 19         1.000000    1.000000   8.551901e+08              1.0
# 21        10.000000    2.000000   8.531575e+08              1.0
# 22        32.000000    1.000000   1.131662e+09              1.0
# 23         1.000000    0.500000   1.148386e+09              1.0
# 26         1.000000    0.500000   1.351544e+09              1.0
# 30         1.000000    1.000000   9.449431e+08              1.0
# 33        19.000000    1.000000   1.032677e+09              1.0
# 34         6.000000    1.000000   9.737462e+08              1.0
# 36         6.000000    2.000000   8.470565e+08              1.0
# 38        16.000000    3.000000   1.389721e+09              1.0
# 41         2.000000    2.500000   1.093887e+09              1.0
# 43         1.000000    1.000000   9.747567e+08              1.0
# 48         1.000000    1.500000   1.303371e+09              1.0
# 56         1.000000    1.000000   1.467003e+09              1.0
# 57        11.000000    1.000000   9.077618e+08              1.0
# 61         2.000000    0.500000   1.216050e+09              1.0
# Есть мнение, что "раньше снимали настоящее кино, не то что сейчас". 
# Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из материалов занятия. 
# Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
 
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, 
# а пройдемся по следующему алгоритму:
 
# 1. В переменную years запишите список из всех годов с 1950 по 2010.
# 2. Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. 
#  Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
# - для каждой строки пройдите по всем годам списка years
# - если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
# - если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
# 3. Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец 'year'
# 4. Посчитайте средний рейтинг всех фильмов для каждого значения столбца 'year' и отсортируйте результат 
# по убыванию рейтинга

import pandas as pd
df_movies = pd.read_csv("csvs/movies.csv")
df_ratings = pd.read_csv("csvs/ratings.csv")
years = [y for y in range(1950, 2011)]

def production_year(title):    
    for year in years:
        if "%d" % year in title[1]:
            return year
        
    return 1900

df_merge = df_ratings.join(df_movies.set_index('movieId'), on='movieId')
rating = df_merge.groupby('movieId')['rating'].mean()
df_merged = df_movies.join(rating, on='movieId')

for movie in df_merged.iterrows():
    id_movie = movie[0]
    title = movie[1]
    df_merged.at[id_movie, 'year'] = production_year(title)

df_merged.groupby('year')['rating'].mean().sort_values(ascending=False)
# Out:
# year
# 1951.0    3.906653
# 1952.0    3.802318
# 1962.0    3.772962
# 1953.0    3.738878
# 1957.0    3.693322
# 1973.0    3.688212
# 1971.0    3.643227
# 1969.0    3.604509
# 1972.0    3.585295
# 1958.0    3.571956
# 1977.0    3.561309
# 1970.0    3.559196
# 1976.0    3.555585
# 1964.0    3.541368
# 1960.0    3.521093
# 1965.0    3.517831
# 1954.0    3.499630
# 1955.0    3.494027
# 1978.0    3.480250
# 1963.0    3.476131
# 1974.0    3.474349
# 1959.0    3.451465
# 1961.0    3.447639
# 1950.0    3.436538
# 1981.0    3.433803
# 1984.0    3.421947
# 1982.0    3.389581
# 1979.0    3.385841
# 2007.0    3.380247
# 1967.0    3.371085
#             ...
# 1995.0    3.337819
# 1992.0    3.335977
# 2005.0    3.333775
# 1985.0    3.331014
# 1986.0    3.322234
# 1956.0    3.319404
# 2004.0    3.300785
# 1993.0    3.281731
# 1968.0    3.272118
# 1994.0    3.269216
# 1998.0    3.266041
# 2006.0    3.265219
# 1996.0    3.260178
# 1987.0    3.247274
# 1900.0    3.245485
# 1989.0    3.245381
# 1988.0    3.242909
# 2008.0    3.237304
# 1980.0    3.221179
# 1991.0    3.214035
# 2009.0    3.212944
# 1983.0    3.205512
# 1999.0    3.201568
# 2010.0    3.201324
# 2000.0    3.194736
# 2002.0    3.191918
# 1997.0    3.183169
# 1990.0    3.166759
# 2003.0    3.154081
# 2001.0    3.133080
# Name: rating, Length: 62, dtype: float64
